# %% [markdown]
# # Introdução à Ciência de Dados - UFPB
# Professor: Yuri Malheiros
#
# ## Correlação

# %% [markdown]
# Colete os seguintes dados dos times do campeonato brasileiro de 2020:
#
# - Pontos
# - Gols marcados
# - Gol sofridos
#
# Você pode encontrar esses dados no site da CBF (www.cbf.com.br)
#
# Calcule a correlação entre:
#
# - Pontos e gols marcados
# - Pontos e gols sofridos

# %% [markdown]
# ## Dados

# %%
import pandas as pd

pontos_dict = {'Flamengo - RJ': 71,
          'Internacional - RS': 70,
          'Atlético - MG': 68,
          'São Paulo - SP': 66,
          'Fluminense - RJ': 64,
          'Grêmio - RS': 59,
          'Palmeiras - SP': 58,
          'Santos - SP': 54,
          'Athletico Paranaense - PR': 53,
          'Red Bull Bragantino - SP': 53,
          'Ceará - CE': 52,
          'Corinthians - SP': 51,
          'Atlético - GO': 50,
          'Bahia - BA': 44,
          'Sport - PE': 42,
          'Fortaleza - CE': 41,
          'Vasco da Gama - RJ': 41,
          'Goiás - GO': 37,
          'Coritiba - PR': 31,
          'Botafogo - RJ': 27}

gols_marcados_dict = {'Flamengo - RJ': 68,
                  'Internacional - RS': 61,
                  'Atlético - MG': 64,
                  'São Paulo - SP': 59,
                  'Fluminense - RJ': 55,
                  'Grêmio - RS': 53,
                  'Palmeiras - SP': 51,
                  'Santos - SP': 52,
                  'Athletico Paranaense - PR': 38,
                  'Red Bull Bragantino - SP': 50,
                  'Ceará - CE': 54,
                  'Corinthians - SP': 45,
                  'Atlético - GO': 40,
                  'Bahia - BA': 48,
                  'Sport - PE': 31,
                  'Fortaleza - CE': 34,
                  'Vasco da Gama - RJ': 37,
                  'Goiás - GO': 41,
                  'Coritiba - PR': 31,
                  'Botafogo - RJ': 32}

gols_sofridos_dict = {'Flamengo - RJ': 48,
                  'Internacional - RS': 35,
                  'Atlético - MG': 45,
                  'São Paulo - SP': 41,
                  'Fluminense - RJ': 42,
                  'Grêmio - RS': 40,
                  'Palmeiras - SP': 37,
                  'Santos - SP': 51,
                  'Athletico Paranaense - PR': 36,
                  'Red Bull Bragantino - SP': 40,
                  'Ceará - CE': 51,
                  'Corinthians - SP': 45,
                  'Atlético - GO': 45,
                  'Bahia - BA': 59,
                  'Sport - PE': 50,
                  'Fortaleza - CE': 44,
                  'Vasco da Gama - RJ': 56,
                  'Goiás - GO': 63,
                  'Coritiba - PR': 54,
                  'Botafogo - RJ': 62}

pontos = pd.Series(pontos_dict)
gols_marcados = pd.Series(gols_marcados_dict)
gols_sofridos = pd.Series(gols_sofridos_dict)

campeonato = pd.DataFrame({"Pontos": pontos, "Gols_Marcados": gols_marcados, "Gols_Sofridos": gols_sofridos})
campeonato
# Out:
#                            Pontos  Gols_Marcados  Gols_Sofridos
# Flamengo - RJ                  71             68             48
# Internacional - RS             70             61             35
# Atlético - MG                  68             64             45
# São Paulo - SP                 66             59             41
# Fluminense - RJ                64             55             42
# Grêmio - RS                    59             53             40
# Palmeiras - SP                 58             51             37
# Santos - SP                    54             52             51
# Athletico Paranaense - PR      53             38             36
# Red Bull Bragantino - SP       53             50             40
# Ceará - CE                     52             54             51
# Corinthians - SP               51             45             45
# Atlético - GO                  50             40             45
# Bahia - BA                     44             48             59
# ...

# %% [markdown]
# ### Correlação entre Pontos e gols marcados

# %%
campeonato[["Pontos", "Gols_Marcados"]].corr()
# Out:
#                  Pontos  Gols_Marcados
# Pontos         1.000000       0.905261
# Gols_Marcados  0.905261       1.000000

# %% [markdown]
# ### Correlação entre Pontos e gols sofridos

# %%
campeonato[["Pontos", "Gols_Sofridos"]].corr()
# Out:
#                  Pontos  Gols_Sofridos
# Pontos         1.000000      -0.708773
# Gols_Sofridos -0.708773       1.000000

# %% [markdown]
# ### Análise dos Resultados
#
# Qual o nível (fraco, moderado, forte) das correlações entre as variáveis analisadas?

# %% [markdown]
# Pontos e gols marcados =  0.90, Muito forte segunda a tabela e São Correlacionadas
# Pontos e gols sofridos = -0.70, Fortes e São AntiCorrelacionadas

# %% [markdown]
# De acordo com os dados analisados, é melhor um time focar em marcar mais gols ou sofrer menos gols?

# %% [markdown]
# Acho que o ideia seria fazer os dois, tanto marcar mais gols e sofrer menos, mas dentre eles a prioridade pode ser Marcar mais gols pois isso resultaria em maior quantidade de vitorias assim aumentando os pontos em maior quantidade.
